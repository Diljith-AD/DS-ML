# %%
import matplotlib.pyplot as plt
data_students=[5,15,25,35,45,55]
plt.hist(data_students,bins=[0,10,20,30,40,50,60],weights=[20,10,45,33,6,8],edgecolor="red")
plt.show()

# %%
import numpy as np

# %%
data_students=[1,11,21,31,41,51]
plt.hist(data_students,bins=[0,10,20,30,40,50,60],weights=[10,1,0,33,6,8],facecolor="y",edgecolor="red")
plt.title("Histogram for students data")
plt.xlabel("value")
plt.ylabel("Frequency")
plt.savefig("student.png")
plt.show()

# %%
list1=[43,76,34,63,56,82,87,55,64,87,95,23,14,65,67,23,85]
list2=[34,45,34,23,43,76,26,18,24,74,23,56,23,23,34,56,32,23]
data=[list1,list2]
plt.boxplot(data)
plt.show()

# %%
value1=[72,76,24,40,57,62,75,78,31,32]
value2=[62,5,91,25,36,32,96,95,30,90]
value3=[23,89,12,78,72,89,25,69,68,86]
value4=[99,73,70,16,81,61,88,98,10,87]
box_plot_data=[value1,value2,value3,value4]
box=plt.boxplot(box_plot_data,vert=1,patch_artist=True,labels=['course1','course2','course3','course4'])
colors=['cyan','lightblue','lightgreen','tan']
for patch,color in zip(box['boxes'],colors):
    patch.set_facecolor(color)
plt.show()

# %%
weight=[83.3,74,64.5,79,90,84.8,84,88,66,77,79,90.5,74.3,90,73]
height=[167,113.7,124.8,165.5,145.4,155,149,180,169.5,156,167.3,145,185,181,168.3]
plt.scatter(weight,height,c="r",marker="*")
plt.xlabel("weight",fontsize=16)
plt.ylabel("heignt",fontsize=16)
plt.title("Scatter plot height vs weight",fontsize=20)
plt.show()

# %%
men=[22,30,35,35,26]
women=[25,32,30,35,29]
  
X_axis = np.arange(len(men)) 
  
plt.bar(X_axis - 0.2, men, 0.4, label = 'Men',color='b') 
plt.bar(X_axis + 0.2, women, 0.4, label = 'Women',color="pink") 
  
 
plt.legend() 
plt.show()

# %%
weight=[78,72,69,81,63,67,65,79,74,71,83,71,79,80]
plt.hist(weight,bins=5,edgecolor="black")
plt.title("Simple Histogram")
plt.xlabel("Weight")
plt.ylabel("freguency")
plt.show()

# %%
weight=[78,72,69,81,63,67,65,79,74,71,83,71,79,80]
plt.hist(weight,bins=5, orientation="horizontal",edgecolor="black")
plt.title("Simple Histogram")
plt.xlabel("Weight")
plt.ylabel("freguency")
plt.show()

# %%
weight=[78,72,69,81,63,67,65,79,74,71,83,71,79,80]
plt.hist(weight,bins=5,histtype="step",edgecolor="black",facecolor="blue")
plt.title("Simple Histogram")
plt.xlabel("Weight")
plt.ylabel("freguency")
plt.show()

# %%
import matplotlib.pyplot as plt

weight = [78, 72, 69, 81, 63, 67, 65, 79, 74, 71, 83, 71, 79, 80]

plt.hist(weight, bins=5, edgecolor='black', color='blue', alpha=0.7)
plt.title('Simple Histogram')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.show()
